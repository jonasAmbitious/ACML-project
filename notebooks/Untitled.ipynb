# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

# %%
# Relu with Adadelta optimizer

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape, y_train.shape)

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)
 
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

batch_size = 128
num_classes = 10
epochs = 100

model = Sequential()
model.add(Conv2D(32, kernel_size=(5, 5),activation='sigmoid',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='sigmoid'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='sigmoid'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adadelta(), metrics=['accuracy'])

hist = model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")

score = model.evaluate(x_test, y_test, verbose=0)


# to save in a csv
import csv 
with open('sigmoidAda.csv', 'w') as f:
    feildnames = ['loss', 'accuracy']
    thewriter = csv.DictWriter(f, feildnames)
    thewriter.writeheader()
    
    thewriter.writerow({'loss':score[0],'accuracy': score[1]})

print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save('sigmoidAda.h5')  

print("sigmoidAda.h5")
# Out:
# (60000, 28, 28) (60000,)
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/100
# 469/469 [==============================] - 17s 36ms/step - loss: 2.6388 - accuracy: 0.0992 - val_loss: 2.3973 - val_accuracy: 0.0980
# Epoch 2/100
# 469/469 [==============================] - 18s 38ms/step - loss: 2.5897 - accuracy: 0.0986 - val_loss: 2.3653 - val_accuracy: 0.0980
# Epoch 3/100
# 469/469 [==============================] - 20s 42ms/step - loss: 2.5524 - accuracy: 0.0991 - val_loss: 2.3454 - val_accuracy: 0.0980
# Epoch 4/100
# 469/469 [==============================] - 20s 42ms/step - loss: 2.5291 - accuracy: 0.0995 - val_loss: 2.3329 - val_accuracy: 0.0980
# Epoch 5/100
# 469/469 [==============================] - 20s 42ms/step - loss: 2.5139 - accuracy: 0.0992 - val_loss: 2.3249 - val_accuracy: 0.0980
# Epoch 6/100
# 469/469 [==============================] - 20s 43ms/step - loss: 2.4979 - accuracy: 0.0987 - val_loss: 2.3195 - val_accuracy: 0.0980
# ...

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape, y_train.shape)

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)
 
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

batch_size = 128
num_classes = 10
epochs = 100

model = Sequential()
model.add(Conv2D(32, kernel_size=(5, 5),activation='relu',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adadelta(), metrics=['accuracy'])

hist = model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")

score = model.evaluate(x_test, y_test, verbose=0)


# to save in a csv
import csv 
with open('reluAda.csv', 'w') as f:
    feildnames = ['loss', 'accuracy']
    thewriter = csv.DictWriter(f, feildnames)
    thewriter.writeheader()
    thewriter.writerow({'loss':score[0],'accuracy': score[1]})

print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save('reluAda.h5')  

print("reluAda.h5")
# Out:
# (60000, 28, 28) (60000,)
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/100
# 469/469 [==============================] - 20s 43ms/step - loss: 2.3069 - accuracy: 0.0990 - val_loss: 2.2911 - val_accuracy: 0.1130
# Epoch 2/100
# 469/469 [==============================] - 20s 42ms/step - loss: 2.2912 - accuracy: 0.1164 - val_loss: 2.2740 - val_accuracy: 0.1595
# Epoch 3/100
# 469/469 [==============================] - 20s 42ms/step - loss: 2.2746 - accuracy: 0.1426 - val_loss: 2.2575 - val_accuracy: 0.2144
# Epoch 4/100
# 469/469 [==============================] - 20s 42ms/step - loss: 2.2613 - accuracy: 0.1656 - val_loss: 2.2407 - val_accuracy: 0.2680
# Epoch 5/100
# 469/469 [==============================] - 20s 42ms/step - loss: 2.2478 - accuracy: 0.1853 - val_loss: 2.2229 - val_accuracy: 0.3288
# Epoch 6/100
# 469/469 [==============================] - 20s 42ms/step - loss: 2.2307 - accuracy: 0.2113 - val_loss: 2.2029 - val_accuracy: 0.3709
# ...

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape, y_train.shape)

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)
 
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

batch_size = 128
num_classes = 10
epochs = 10

model = Sequential()
model.add(Conv2D(32, kernel_size=(5, 5),activation='tanh',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='tanh'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='tanh'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adadelta(), metrics=['accuracy'])

hist = model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")

score = model.evaluate(x_test, y_test, verbose=0)


# to save in a csv
import csv 
with open('tanhAda.csv', 'w') as f:
    feildnames = ['loss', 'accuracy']
    thewriter = csv.DictWriter(f, feildnames)
    thewriter.writeheader()
    thewriter.writerow({'loss':score[0],'accuracy': score[1]})

print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save('tanh.h5')  

print("tanh.h5")
# Out:
# (60000, 28, 28) (60000,)
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/10
# 469/469 [==============================] - 33s 70ms/step - loss: 2.3372 - accuracy: 0.1073 - val_loss: 2.2544 - val_accuracy: 0.1935
# Epoch 2/10
# 469/469 [==============================] - 31s 66ms/step - loss: 2.2497 - accuracy: 0.1662 - val_loss: 2.1711 - val_accuracy: 0.3768
# Epoch 3/10
# 469/469 [==============================] - 31s 66ms/step - loss: 2.1680 - accuracy: 0.2448 - val_loss: 2.0902 - val_accuracy: 0.4968
# Epoch 4/10
# 469/469 [==============================] - 31s 66ms/step - loss: 2.0901 - accuracy: 0.3244 - val_loss: 2.0085 - val_accuracy: 0.5787
# Epoch 5/10
# 469/469 [==============================] - 31s 67ms/step - loss: 2.0109 - accuracy: 0.3964 - val_loss: 1.9242 - val_accuracy: 0.6200
# Epoch 6/10
# 469/469 [==============================] - 32s 68ms/step - loss: 1.9292 - accuracy: 0.4571 - val_loss: 1.8379 - val_accuracy: 0.6404
# ...

# %%
#changing the optimizer to Adam()

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape, y_train.shape)

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)
 
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

batch_size = 128
num_classes = 10
epochs = 100

model = Sequential()

model.add(Conv2D(32, kernel_size=(5, 5),activation='sigmoid',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='sigmoid'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='sigmoid'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

hist = model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")

score = model.evaluate(x_test, y_test, verbose=0)


# to save in a csv
import csv 
with open('sigmoidAdam.csv', 'w') as f:
    feildnames = ['loss', 'accuracy']
    thewriter = csv.DictWriter(f, feildnames)
    thewriter.writeheader()
    thewriter.writerow({'loss':score[0],'accuracy': score[1]})

print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save('sigmoidAdam.h5')  

print("sigmoidAdam.h5")
# Out:
# (60000, 28, 28) (60000,)
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/100
# 469/469 [==============================] - 20s 43ms/step - loss: 2.3210 - accuracy: 0.1016 - val_loss: 2.3013 - val_accuracy: 0.1135
# Epoch 2/100
# 469/469 [==============================] - 17s 37ms/step - loss: 2.3025 - accuracy: 0.1087 - val_loss: 2.3001 - val_accuracy: 0.1135
# Epoch 3/100
# 469/469 [==============================] - 18s 38ms/step - loss: 0.9862 - accuracy: 0.6747 - val_loss: 0.1616 - val_accuracy: 0.9564
# Epoch 4/100
# 469/469 [==============================] - 19s 41ms/step - loss: 0.2187 - accuracy: 0.9460 - val_loss: 0.0871 - val_accuracy: 0.9738
# Epoch 5/100
# 469/469 [==============================] - 22s 47ms/step - loss: 0.1462 - accuracy: 0.9633 - val_loss: 0.0693 - val_accuracy: 0.9791
# Epoch 6/100
# 469/469 [==============================] - 20s 43ms/step - loss: 0.1178 - accuracy: 0.9697 - val_loss: 0.0612 - val_accuracy: 0.9820
# ...

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape, y_train.shape)

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)
 
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

batch_size = 128
num_classes = 10
epochs = 100

model = Sequential()

model.add(Conv2D(32, kernel_size=(5, 5),activation='tanh',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='tanh'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='tanh'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

hist = model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")

score = model.evaluate(x_test, y_test, verbose=0)


# to save in a csv
import csv 
with open('tanhAdam.csv', 'w') as f:
    feildnames = ['loss', 'accuracy']
    thewriter = csv.DictWriter(f, feildnames)
    thewriter.writeheader()
    thewriter.writerow({'loss':score[0],'accuracy': score[1]})

print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save('tanhAdam.h5')  

print("tanhAdam.h5")
# Out:
# (60000, 28, 28) (60000,)
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/100
# 469/469 [==============================] - 32s 67ms/step - loss: 0.2689 - accuracy: 0.9218 - val_loss: 0.0637 - val_accuracy: 0.9803
# Epoch 2/100
# 469/469 [==============================] - 31s 65ms/step - loss: 0.0936 - accuracy: 0.9737 - val_loss: 0.0491 - val_accuracy: 0.9832
# Epoch 3/100
# 469/469 [==============================] - 31s 66ms/step - loss: 0.0748 - accuracy: 0.9787 - val_loss: 0.0383 - val_accuracy: 0.9873
# Epoch 4/100
# 469/469 [==============================] - 31s 65ms/step - loss: 0.0650 - accuracy: 0.9818 - val_loss: 0.0378 - val_accuracy: 0.9875
# Epoch 5/100
# 469/469 [==============================] - 30s 65ms/step - loss: 0.0539 - accuracy: 0.9847 - val_loss: 0.0401 - val_accuracy: 0.9871
# Epoch 6/100
# 469/469 [==============================] - 31s 65ms/step - loss: 0.0514 - accuracy: 0.9853 - val_loss: 0.0455 - val_accuracy: 0.9869
# ...

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape, y_train.shape)

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)
 
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

batch_size = 128
num_classes = 10
epochs = 100

model = Sequential()

model.add(Conv2D(32, kernel_size=(5, 5),activation='relu',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

hist = model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")

score = model.evaluate(x_test, y_test, verbose=0)


# to save in a csv
import csv 
with open('reluAdam.csv', 'w') as f:
    feildnames = ['loss', 'accuracy']
    thewriter = csv.DictWriter(f, feildnames)
    thewriter.writeheader()
    thewriter.writerow({'loss':score[0],'accuracy': score[1]})

print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save('reluAdam.h5')  

print("reluAdam.h5")
# Out:
# (60000, 28, 28) (60000,)
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.3843 - accuracy: 0.8793 - val_loss: 0.0589 - val_accuracy: 0.9822
# Epoch 2/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.1084 - accuracy: 0.9707 - val_loss: 0.0373 - val_accuracy: 0.9883
# Epoch 3/100
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0771 - accuracy: 0.9790 - val_loss: 0.0340 - val_accuracy: 0.9897
# Epoch 4/100
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0610 - accuracy: 0.9843 - val_loss: 0.0306 - val_accuracy: 0.9909
# Epoch 5/100
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0540 - accuracy: 0.9862 - val_loss: 0.0363 - val_accuracy: 0.9883
# Epoch 6/100
# 469/469 [==============================] - 20s 43ms/step - loss: 0.0484 - accuracy: 0.9874 - val_loss: 0.0273 - val_accuracy: 0.9916
# ...

# %%
#Changing the optimizer

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape, y_train.shape)

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)
 
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

batch_size = 128
num_classes = 10
epochs = 100

model = Sequential()

model.add(Conv2D(32, kernel_size=(5, 5),activation='relu',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])

hist = model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")

score = model.evaluate(x_test, y_test, verbose=0)


# to save in a csv
import csv 
with open('reluRMSprop.csv', 'w') as f:
    feildnames = ['loss', 'accuracy']
    thewriter = csv.DictWriter(f, feildnames)
    thewriter.writeheader()
    thewriter.writerow({'loss':score[0],'accuracy': score[1]})

print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save('reluRMSprop.h5')  

print("reluRMSprop.h5")
# Out:
# (60000, 28, 28) (60000,)
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/100
# 469/469 [==============================] - 32s 68ms/step - loss: 0.3759 - accuracy: 0.8858 - val_loss: 0.0612 - val_accuracy: 0.9814
# Epoch 2/100
# 469/469 [==============================] - 31s 65ms/step - loss: 0.1069 - accuracy: 0.9724 - val_loss: 0.0435 - val_accuracy: 0.9875
# Epoch 3/100
# 469/469 [==============================] - 29s 62ms/step - loss: 0.0733 - accuracy: 0.9806 - val_loss: 0.0420 - val_accuracy: 0.9879
# Epoch 4/100
# 469/469 [==============================] - 29s 62ms/step - loss: 0.0597 - accuracy: 0.9852 - val_loss: 0.0352 - val_accuracy: 0.9901
# Epoch 5/100
# 469/469 [==============================] - 29s 63ms/step - loss: 0.0513 - accuracy: 0.9879 - val_loss: 0.0372 - val_accuracy: 0.9905
# Epoch 6/100
# 469/469 [==============================] - 29s 63ms/step - loss: 0.0451 - accuracy: 0.9887 - val_loss: 0.0365 - val_accuracy: 0.9903
# ...

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape, y_train.shape)

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)
 
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

batch_size = 128
num_classes = 10
epochs = 100

model = Sequential()

model.add(Conv2D(32, kernel_size=(5, 5),activation='sigmoid',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='sigmoid'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='sigmoid'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])

hist = model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")

score = model.evaluate(x_test, y_test, verbose=0)


# to save in a csv
import csv 
with open('sigmoidRMSprop.csv', 'w') as f:
    feildnames = ['loss', 'accuracy']
    thewriter = csv.DictWriter(f, feildnames)
    thewriter.writeheader()
    thewriter.writerow({'loss':score[0],'accuracy': score[1]})

print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save('sigmoidRMSprop.h5')  

print("sigmoidRMSprop.h5")
# Out:
# (60000, 28, 28) (60000,)
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/100
# 469/469 [==============================] - 16s 35ms/step - loss: 1.6656 - accuracy: 0.4159 - val_loss: 0.5671 - val_accuracy: 0.8536
# Epoch 2/100
# 469/469 [==============================] - 18s 37ms/step - loss: 0.5016 - accuracy: 0.8608 - val_loss: 0.2216 - val_accuracy: 0.9400
# Epoch 3/100
# 469/469 [==============================] - 20s 42ms/step - loss: 0.2572 - accuracy: 0.9319 - val_loss: 0.1089 - val_accuracy: 0.9652
# Epoch 4/100
# 469/469 [==============================] - 21s 46ms/step - loss: 0.1713 - accuracy: 0.9539 - val_loss: 0.0784 - val_accuracy: 0.9744
# Epoch 5/100
# 469/469 [==============================] - 20s 43ms/step - loss: 0.1335 - accuracy: 0.9646 - val_loss: 0.0774 - val_accuracy: 0.9787
# Epoch 6/100
# 469/469 [==============================] - 20s 43ms/step - loss: 0.1105 - accuracy: 0.9707 - val_loss: 0.0595 - val_accuracy: 0.9821
# ...

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape, y_train.shape)

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)
 
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

batch_size = 128
num_classes = 10
epochs = 100

model = Sequential()

model.add(Conv2D(32, kernel_size=(5, 5),activation='tanh',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='tanh'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='tanh'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])

hist = model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")

score = model.evaluate(x_test, y_test, verbose=0)


# to save in a csv
import csv 
with open('tanhRMSprop.csv', 'w') as f:
    feildnames = ['loss', 'accuracy']
    thewriter = csv.DictWriter(f, feildnames)
    thewriter.writeheader()
    thewriter.writerow({'loss':score[0],'accuracy': score[1]})

print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save('tanhRMSprop.h5')  

print("tanhRMSprop.h5")
# Out:
# (60000, 28, 28) (60000,)
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/100
# 469/469 [==============================] - 33s 70ms/step - loss: 0.2418 - accuracy: 0.9322 - val_loss: 0.0622 - val_accuracy: 0.9805
# Epoch 2/100
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0973 - accuracy: 0.9720 - val_loss: 0.0525 - val_accuracy: 0.9838
# Epoch 3/100
# 469/469 [==============================] - 31s 67ms/step - loss: 0.0734 - accuracy: 0.9788 - val_loss: 0.0434 - val_accuracy: 0.9878
# Epoch 4/100
# 469/469 [==============================] - 31s 66ms/step - loss: 0.0597 - accuracy: 0.9826 - val_loss: 0.0347 - val_accuracy: 0.9899
# Epoch 5/100
# 469/469 [==============================] - 31s 67ms/step - loss: 0.0525 - accuracy: 0.9855 - val_loss: 0.0355 - val_accuracy: 0.9893
# Epoch 6/100
# 469/469 [==============================] - 32s 67ms/step - loss: 0.0461 - accuracy: 0.9868 - val_loss: 0.0316 - val_accuracy: 0.9898
# ...
